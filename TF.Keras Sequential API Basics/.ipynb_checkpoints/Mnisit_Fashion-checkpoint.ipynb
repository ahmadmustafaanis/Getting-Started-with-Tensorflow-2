# %%
import tensorflow as tf 
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D

# %%
from tensorflow.keras.models import Sequential

# %%
from keras.datasets import fashion_mnist
# Out:
# Using TensorFlow backend.

# %%
(train_images,train_labels),(test_images,test_labels) = fashion_mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
model = Sequential([
    Conv2D(16, kernel_size=3, strides=(2,2), activation='relu', input_shape=(28,28,1)),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(64,activation='relu'),
    Dense(10,activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 13, 13, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 6, 6, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                36928
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 37,738
# Trainable params: 37,738
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images = train_images / 255
test_images = test_images / 255

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
labels = [
    'T-shirt/top',
    'Trouser',
    'Pullover',
    'Dress',
    'Coat',
    'Sandal',
    'Shirt',
    'Sneaker',
    'Bag',
    'Ankle boot'
]

# %%
plt.imshow(train_images[0])
print(labels[train_labels[0]])
# Out:
# Ankle boot

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005),
             loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             metrics=[tf.keras.metrics.SparseCategoricalAccuracy(),tf.keras.metrics.MeanAbsoluteError()]
             )

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 13, 13, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 6, 6, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                36928
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 37,738
# Trainable params: 37,738
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_images[...,np.newaxis], train_labels, epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4758 - sparse_categorical_accuracy: 0.8264 - mean_absolute_error: 4.4200
# Epoch 2/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3513 - sparse_categorical_accuracy: 0.8703 - mean_absolute_error: 4.4200
# Epoch 3/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3191 - sparse_categorical_accuracy: 0.8805 - mean_absolute_error: 4.4200
# Epoch 4/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2977 - sparse_categorical_accuracy: 0.8870 - mean_absolute_error: 4.4200
# Epoch 5/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2819 - sparse_categorical_accuracy: 0.8949 - mean_absolute_error: 4.4200
# Epoch 6/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2681 - sparse_categorical_accuracy: 0.8986 - mean_absolute_error: 4.4200
# Epoch 7/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2556 - sparse_categorical_accuracy: 0.9032 - mean_absolute_error: 4.4200
# Epoch 8/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2462 - sparse_categorical_accuracy: 0.9074 - mean_absolute_error: 4.4200
# Epoch 9/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2392 - sparse_categorical_accuracy: 0.9089 - mean_absolute_error: 4.4200
# Epoch 10/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2291 - sparse_categorical_accuracy: 0.9128 - mean_absolute_error: 4.4200
# Epoch 11/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2216 - sparse_categorical_accuracy: 0.9155 - mean_absolute_error: 4.4200
# Epoch 12/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2157 - sparse_categorical_accuracy: 0.9171 - mean_absolute_error: 4.4200
# Epoch 13/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2093 - sparse_categorical_accuracy: 0.9196 - mean_absolute_error: 4.4200
# Epoch 14/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2052 - sparse_categorical_accuracy: 0.9217 - mean_absolute_error: 4.4200
# Epoch 15/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1995 - sparse_categorical_accuracy: 0.9238 - mean_absolute_error: 4.4200
# Epoch 16/20
# 1863/1875 [============================>.] - ETA: 0s - loss: 0.1942 - sparse_categorical_accuracy: 0.9261 - mean_absolute_error: 4.4201875/1875 [==============================] - 5s 3ms/step - loss: 0.1940 - sparse_categorical_accuracy: 0.9262 - mean_absolute_error: 4.4200
# Epoch 17/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1914 - sparse_categorical_accuracy: 0.9263 - mean_absolute_error: 4.4200
# Epoch 18/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1894 - sparse_categorical_accuracy: 0.9275 - mean_absolute_error: 4.4200
# Epoch 19/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1822 - sparse_categorical_accuracy: 0.9297 - mean_absolute_error: 4.4200
# Epoch 20/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1785 - sparse_categorical_accuracy: 0.9306 - mean_absolute_error: 4.4200

# %%
df = pd.DataFrame(history.history)

# %%
df.head()
# Out:
#        loss  sparse_categorical_accuracy  mean_absolute_error
# 0  0.475756                     0.826400             4.420010
# 1  0.351348                     0.870267             4.420004
# 2  0.319061                     0.880517             4.420011
# 3  0.297707                     0.886983             4.420004
# 4  0.281917                     0.894850             4.420010

# %%
plt.plot(df['sparse_categorical_accuracy'])
plt.xlabel("Epochs")
plt.ylabel('Accuracy')
plt.show()

# %%
plt.plot(df['loss'].astype('float64'))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
loss, sparse_accuracy,mse = model.evaluate(test_images[...,np.newaxis], test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4396 - sparse_categorical_accuracy: 0.8791 - mean_absolute_error: 4.4200

# %%
# Out:
# 0.4395844638347626

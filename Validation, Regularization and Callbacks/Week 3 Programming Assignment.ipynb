# %% [markdown]
# # Programming Assignment

# %% [markdown]
# ## Model validation on the Iris dataset

# %% [markdown]
# ### Instructions
#
# In this notebook, you will build, compile and fit a neural network model to the Iris dataset. You will also implement validation, regularisation and callbacks to improve your model.
#
# Some code cells are provided you in the notebook. You should avoid editing provided code, and make sure to execute the cells in order to avoid unexpected errors. Some cells begin with the line:
#
# `#### GRADED CELL ####`
#
# Don't move or edit this first line - this is what the automatic grader looks for to recognise graded cells. These cells require you to write your own code to complete them, and are automatically graded when you submit the notebook. Don't edit the function name or signature provided in these cells, otherwise the automatic grader might not function properly. Inside these graded cells, you can use any functions or classes that are imported below, but make sure you don't use any variables that are outside the scope of the function.
#
# ### How to submit
#
# Complete all the tasks you are asked for in the worksheet. When you have finished and are happy with your code, press the **Submit Assignment** button at the top of this notebook.
#
# ### Let's get started!
#
# We'll start running some imports, and loading the dataset. Do not edit the existing imports in the following cell. If you would like to make further Tensorflow imports, you should add them here.

# %%
#### PACKAGE IMPORTS ####

# Run this cell first to import all required packages. Do not make any imports elsewhere in the notebook
from numpy.random import seed
seed(8)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, model_selection 
# %matplotlib inline

# If you would like to make further imports from tensorflow, add them here
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %% [markdown]
# <tr>
# <td><img src="data/iris_setosa.jpg" alt="Drawing" style="height: 270px;"/></td>
# <td><img src="data/iris_versicolor.jpg" alt="Drawing" style="height: 270px;"/></td>
# <td><img src="data/iris_virginica.jpg" alt="Drawing" style="height: 270px;"/></td>
# </tr>

# %% [markdown]
# #### The Iris dataset
#
# In this assignment, you will use the [Iris dataset](https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html). It consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters. For a reference, see the following papers:
#
# - R. A. Fisher. "The use of multiple measurements in taxonomic problems". Annals of Eugenics. 7 (2): 179–188, 1936.
#
# Your goal is to construct a neural network that classifies each sample into the correct class, as well as applying validation and regularisation techniques.

# %% [markdown]
# #### Load and preprocess the data
#
# First read in the Iris dataset using `datasets.load_iris()`, and split the dataset into training and test sets.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def read_in_and_split_data(iris_data):
    """
    This function takes the Iris dataset as loaded by sklearn.datasets.load_iris(), and then 
    splits so that the training set includes 90% of the full dataset, with the test set 
    making up the remaining 10%.
    Your function should return a tuple (train_data, test_data, train_targets, test_targets) 
    of appropriately split training and test data and targets.
    
    If you would like to import any further packages to aid you in this task, please do so in the 
    Package Imports cell above.
    """
    X = iris_data['data']
    y = iris_data['target']
    X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.1)
    return X_train, X_test, y_train, y_test

# %%
# Run your function to generate the test and training data.

iris_data = datasets.load_iris()
#print(iris_data.keys())
train_data, test_data , train_targets, test_targets = read_in_and_split_data(iris_data)

# %% [markdown]
# We will now convert the training and test targets using a one hot encoder.

# %%
train_data.shape
# Out:
# (15, 4)

# %%
# Convert targets to a one-hot encoding

train_targets = tf.keras.utils.to_categorical(np.array(train_targets))
test_targets = tf.keras.utils.to_categorical(np.array(test_targets))

# %% [markdown]
# #### Build the neural network model

# %% [markdown]
# You can now construct a model to fit to the data. Using the Sequential API, build your model according to the following specifications:
#
# * The model should use the `input_shape` in the function argument to set the input size in the first layer.
# * The first layer should be a dense layer with 64 units.
# * The weights of the first layer should be initialised with the He uniform initializer.
# * The biases of the first layer should be all initially equal to one.
# * There should then be a further four dense layers, each with 128 units.
# * This should be followed with four dense layers, each with 64 units.
# * All of these Dense layers should use the ReLU activation function.
# * The output Dense layer should have 3 units and the softmax activation function.
#
# In total, the network should have 10 layers.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_model(input_shape):
    """
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should return the model.
    """
    model = Sequential([
        Dense(64, input_shape=input_shape, kernel_initializer=tf.keras.initializers.he_uniform(), bias_initializer='ones', activation='relu'),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(3, activation='softmax')
    ])
    return model

# %%
# Run your function to get the model

model = get_model(train_data[0].shape)

# %% [markdown]
# #### Compile the model
#
# You should now compile the model using the `compile` method. Remember that you need to specify an optimizer, a loss function and a metric to judge the performance of your model.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def compile_model(model):
    """
    This function takes in the model returned from your get_model function, and compiles it with an optimiser,
    loss function and metric.
    Compile the model using the Adam optimiser (with learning rate set to 0.0001), 
    the categorical crossentropy loss function and accuracy as the only metric. 
    Your function doesn't need to return anything; the model will be compiled in-place.
    """
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss=tf.keras.losses.categorical_crossentropy, metrics=['acc'] )

# %%
# Run your function to compile the model

compile_model(model)

# %% [markdown]
# #### Fit the model to the training data
#
# Now you should train the model on the Iris dataset, using the model's `fit` method.
# * Run the training for a fixed number of epochs, given by the function's `epochs` argument.
# * Return the training history to be used for plotting the learning curves.
# * Set the batch size to 40.
# * Set the validation set to be 15% of the training set.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def train_model(model, train_data, train_targets, epochs):
    """
    This function should train the model for the given number of epochs on the 
    train_data and train_targets. 
    Your function should return the training history, as returned by model.fit.
    """
    history = model.fit(train_data, train_targets, epochs = epochs, batch_size=40, validation_split=0.15)
    return history

# %% [markdown]
# Run the following cell to run the training for 800 epochs.

# %%
# Run your function to train the model

history = train_model(model, train_data, train_targets, epochs=800)
# Out:
# 0
# 1/1 [==============================] - 0s 31ms/step - loss: 1.7767e-04 - acc: 1.0000 - val_loss: 3.5604 - val_acc: 0.6667
# Epoch 656/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7650e-04 - acc: 1.0000 - val_loss: 3.5625 - val_acc: 0.6667
# Epoch 657/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7544e-04 - acc: 1.0000 - val_loss: 3.5665 - val_acc: 0.6667
# Epoch 658/800
# 1/1 [==============================] - 0s 31ms/step - loss: 1.7437e-04 - acc: 1.0000 - val_loss: 3.5705 - val_acc: 0.6667
# Epoch 659/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7335e-04 - acc: 1.0000 - val_loss: 3.5713 - val_acc: 0.6667
# Epoch 660/800
# 1/1 [==============================] - 0s 41ms/step - loss: 1.7225e-04 - acc: 1.0000 - val_loss: 3.5728 - val_acc: 0.6667
# Epoch 661/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.7124e-04 - acc: 1.0000 - val_loss: 3.5764 - val_acc: 0.6667
# Epoch 662/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7018e-04 - acc: 1.0000 - val_loss: 3.5803 - val_acc: 0.6667
# Epoch 663/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.6921e-04 - acc: 1.0000 - val_loss: 3.5815 - val_acc: 0.6667
# Epoch 664/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.6809e-04 - acc: 1.0000 - val_loss: 3.5822 - val_acc: 0.6667
# Epoch 665/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.6712e-04 - acc: 1.0000 - val_loss: 3.5849 - val_acc: 0.6667
# Epoch 666/800
# 1/1 [==============================] - 0s 45ms/step - loss: 1.6609e-04 - acc: 1.0000 - val_loss: 3.5889 - val_acc: 0.6667
# Epoch 667/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.6522e-04 - acc: 1.0000 - val_loss: 3.5882 - val_acc: 0.6667
# Epoch 668/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.6418e-04 - acc: 1.0000 - val_loss: 3.5905 - val_acc: 0.6667
# Epoch 669/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.6319e-04 - acc: 1.0000 - val_loss: 3.5953 - val_acc: 0.6667
# Epoch 670/800
# 1/1 [==============================] - 0s 40ms/step - loss: 1.6234e-04 - acc: 1.0000 - val_loss: 3.5950 - val_acc: 0.6667
# Epoch 671/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.6122e-04 - acc: 1.0000 - val_loss: 3.5970 - val_acc: 0.6667
# Epoch 672/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.6031e-04 - acc: 1.0000 - val_loss: 3.6004 - val_acc: 0.6667
# Epoch 673/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.5934e-04 - acc: 1.0000 - val_loss: 3.6020 - val_acc: 0.6667
# Epoch 674/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.5841e-04 - acc: 1.0000 - val_loss: 3.6053 - val_acc: 0.6667
# Epoch 675/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.5748e-04 - acc: 1.0000 - val_loss: 3.6065 - val_acc: 0.6667
# Epoch 676/800
# 1/1 [==============================] - 0s 31ms/step - loss: 1.5656e-04 - acc: 1.0000 - val_loss: 3.6095 - val_acc: 0.6667
# Epoch 677/800
# 1/1 [==============================] - 0s 30ms/step - loss: 1.5564e-04 - acc: 1.0000 - val_loss: 3.6115 - val_acc: 0.6667
# Epoch 678/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.5474e-04 - acc: 1.0000 - val_loss: 3.6140 - val_acc: 0.6667
# Epoch 679/800
# 1/1 [==============================] - 0s 31ms/step - loss: 1.5386e-04 - acc: 1.0000 - val_loss: 3.6142 - val_acc: 0.6667
# Epoch 680/800
# 1/1 [==============================] - 0s 40ms/step - loss: 1.5304e-04 - acc: 1.0000 - val_loss: 3.6173 - val_acc: 0.6667
# Epoch 681/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.5208e-04 - acc: 1.0000 - val_loss: 3.6217 - val_acc: 0.6667
# Epoch 682/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.5129e-04 - acc: 1.0000 - val_loss: 3.6212 - val_acc: 0.6667
# Epoch 683/800
# 1/1 [==============================] - 0s 41ms/step - loss: 1.5037e-04 - acc: 1.0000 - val_loss: 3.6232 - val_acc: 0.6667
# Epoch 684/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.4953e-04 - acc: 1.0000 - val_loss: 3.6276 - val_acc: 0.6667
# Epoch 685/800
# 1/1 [==============================] - 0s 39ms/step - loss: 1.4866e-04 - acc: 1.0000 - val_loss: 3.6285 - val_acc: 0.6667
# Epoch 686/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.4777e-04 - acc: 1.0000 - val_loss: 3.6297 - val_acc: 0.6667
# Epoch 687/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.4696e-04 - acc: 1.0000 - val_loss: 3.6339 - val_acc: 0.6667
# Epoch 688/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.4605e-04 - acc: 1.0000 - val_loss: 3.6364 - val_acc: 0.6667
# Epoch 689/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.4522e-04 - acc: 1.0000 - val_loss: 3.6387 - val_acc: 0.6667
# Epoch 690/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.4443e-04 - acc: 1.0000 - val_loss: 3.6411 - val_acc: 0.6667
# Epoch 691/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.4360e-04 - acc: 1.0000 - val_loss: 3.6421 - val_acc: 0.6667
# Epoch 692/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.4284e-04 - acc: 1.0000 - val_loss: 3.6456 - val_acc: 0.6667
# Epoch 693/800
# 1/1 [==============================] - 0s 38ms/step - loss: 1.4200e-04 - acc: 1.0000 - val_loss: 3.6482 - val_acc: 0.6667
# Epoch 694/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.4123e-04 - acc: 1.0000 - val_loss: 3.6494 - val_acc: 0.6667
# Epoch 695/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.4040e-04 - acc: 1.0000 - val_loss: 3.6524 - val_acc: 0.6667
# Epoch 696/800
# 1/1 [==============================] - ETA: 0s - loss: 1.3964e-04 - acc: 1.0001/1 [==============================] - 0s 38ms/step - loss: 1.3964e-04 - acc: 1.0000 - val_loss: 3.6520 - val_acc: 0.6667
# Epoch 697/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3888e-04 - acc: 1.0000 - val_loss: 3.6546 - val_acc: 0.6667
# Epoch 698/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.3807e-04 - acc: 1.0000 - val_loss: 3.6585 - val_acc: 0.6667
# Epoch 699/800
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3736e-04 - acc: 1.0000 - val_loss: 3.6582 - val_acc: 0.6667
# Epoch 700/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.3656e-04 - acc: 1.0000 - val_loss: 3.6608 - val_acc: 0.6667
# Epoch 701/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3581e-04 - acc: 1.0000 - val_loss: 3.6655 - val_acc: 0.6667
# Epoch 702/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3515e-04 - acc: 1.0000 - val_loss: 3.6646 - val_acc: 0.6667
# Epoch 703/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3434e-04 - acc: 1.0000 - val_loss: 3.6665 - val_acc: 0.6667
# Epoch 704/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3361e-04 - acc: 1.0000 - val_loss: 3.6709 - val_acc: 0.6667
# Epoch 705/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.3285e-04 - acc: 1.0000 - val_loss: 3.6743 - val_acc: 0.6667
# Epoch 706/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.3220e-04 - acc: 1.0000 - val_loss: 3.6740 - val_acc: 0.6667
# Epoch 707/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.3143e-04 - acc: 1.0000 - val_loss: 3.6755 - val_acc: 0.6667
# Epoch 708/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3074e-04 - acc: 1.0000 - val_loss: 3.6801 - val_acc: 0.6667
# Epoch 709/800
# 1/1 [==============================] - 0s 40ms/step - loss: 1.2998e-04 - acc: 1.0000 - val_loss: 3.6842 - val_acc: 0.6667
# Epoch 710/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.2942e-04 - acc: 1.0000 - val_loss: 3.6839 - val_acc: 0.6667
# Epoch 711/800
# 1/1 [==============================] - 0s 38ms/step - loss: 1.2860e-04 - acc: 1.0000 - val_loss: 3.6842 - val_acc: 0.6667
# Epoch 712/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.2798e-04 - acc: 1.0000 - val_loss: 3.6873 - val_acc: 0.6667
# Epoch 713/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.2729e-04 - acc: 1.0000 - val_loss: 3.6923 - val_acc: 0.6667
# Epoch 714/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2668e-04 - acc: 1.0000 - val_loss: 3.6920 - val_acc: 0.6667
# Epoch 715/800
# 1/1 [==============================] - 0s 38ms/step - loss: 1.2585e-04 - acc: 1.0000 - val_loss: 3.6935 - val_acc: 0.6667
# Epoch 716/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2513e-04 - acc: 1.0000 - val_loss: 3.6969 - val_acc: 0.6667
# Epoch 717/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.2450e-04 - acc: 1.0000 - val_loss: 3.6981 - val_acc: 0.6667
# Epoch 718/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.2386e-04 - acc: 1.0000 - val_loss: 3.6990 - val_acc: 0.6667
# Epoch 719/800
# 1/1 [==============================] - 0s 40ms/step - loss: 1.2321e-04 - acc: 1.0000 - val_loss: 3.7025 - val_acc: 0.6667
# Epoch 720/800
# 1/1 [==============================] - 0s 30ms/step - loss: 1.2252e-04 - acc: 1.0000 - val_loss: 3.7053 - val_acc: 0.6667
# Epoch 721/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.2191e-04 - acc: 1.0000 - val_loss: 3.7045 - val_acc: 0.6667
# Epoch 722/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.2129e-04 - acc: 1.0000 - val_loss: 3.7068 - val_acc: 0.6667
# Epoch 723/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.2063e-04 - acc: 1.0000 - val_loss: 3.7119 - val_acc: 0.6667
# Epoch 724/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.2006e-04 - acc: 1.0000 - val_loss: 3.7129 - val_acc: 0.6667
# Epoch 725/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1940e-04 - acc: 1.0000 - val_loss: 3.7127 - val_acc: 0.6667
# Epoch 726/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1876e-04 - acc: 1.0000 - val_loss: 3.7150 - val_acc: 0.6667
# Epoch 727/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1811e-04 - acc: 1.0000 - val_loss: 3.7193 - val_acc: 0.6667
# Epoch 728/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.1751e-04 - acc: 1.0000 - val_loss: 3.7208 - val_acc: 0.6667
# Epoch 729/800
# 1/1 [==============================] - 0s 44ms/step - loss: 1.1689e-04 - acc: 1.0000 - val_loss: 3.7201 - val_acc: 0.6667
# Epoch 730/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1631e-04 - acc: 1.0000 - val_loss: 3.7224 - val_acc: 0.6667
# Epoch 731/800
# 1/1 [==============================] - 0s 40ms/step - loss: 1.1574e-04 - acc: 1.0000 - val_loss: 3.7271 - val_acc: 0.6667
# Epoch 732/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1508e-04 - acc: 1.0000 - val_loss: 3.7299 - val_acc: 0.6667
# Epoch 733/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.1453e-04 - acc: 1.0000 - val_loss: 3.7289 - val_acc: 0.6667
# Epoch 734/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.1392e-04 - acc: 1.0000 - val_loss: 3.7296 - val_acc: 0.6667
# Epoch 735/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.1337e-04 - acc: 1.0000 - val_loss: 3.7331 - val_acc: 0.6667
# Epoch 736/800
# 1/1 [==============================] - 0s 31ms/step - loss: 1.1276e-04 - acc: 1.0000 - val_loss: 3.7390 - val_acc: 0.6667
# Epoch 737/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.1225e-04 - acc: 1.0000 - val_loss: 3.7404 - val_acc: 0.6667
# Epoch 738/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1158e-04 - acc: 1.0000 - val_loss: 3.7385 - val_acc: 0.6667
# Epoch 739/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.1108e-04 - acc: 1.0000 - val_loss: 3.7398 - val_acc: 0.6667
# Epoch 740/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.1058e-04 - acc: 1.0000 - val_loss: 3.7442 - val_acc: 0.6667
# Epoch 741/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.0993e-04 - acc: 1.0000 - val_loss: 3.7502 - val_acc: 0.6667
# Epoch 742/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.0946e-04 - acc: 1.0000 - val_loss: 3.7509 - val_acc: 0.6667
# Epoch 743/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.0881e-04 - acc: 1.0000 - val_loss: 3.7499 - val_acc: 0.6667
# Epoch 744/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.0832e-04 - acc: 1.0000 - val_loss: 3.7516 - val_acc: 0.6667
# Epoch 745/800
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0773e-04 - acc: 1.0000 - val_loss: 3.7561 - val_acc: 0.6667
# Epoch 746/800
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0714e-04 - acc: 1.0000 - val_loss: 3.7602 - val_acc: 0.6667
# Epoch 747/800
# 1/1 [==============================] - 0s 39ms/step - loss: 1.0671e-04 - acc: 1.0000 - val_loss: 3.7597 - val_acc: 0.6667
# Epoch 748/800
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0607e-04 - acc: 1.0000 - val_loss: 3.7585 - val_acc: 0.6667
# Epoch 749/800
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0562e-04 - acc: 1.0000 - val_loss: 3.7603 - val_acc: 0.6667
# Epoch 750/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.0511e-04 - acc: 1.0000 - val_loss: 3.7648 - val_acc: 0.6667
# Epoch 751/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.0448e-04 - acc: 1.0000 - val_loss: 3.7700 - val_acc: 0.6667
# Epoch 752/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.0405e-04 - acc: 1.0000 - val_loss: 3.7710 - val_acc: 0.6667
# Epoch 753/800
# 1/1 [==============================] - 0s 51ms/step - loss: 1.0348e-04 - acc: 1.0000 - val_loss: 3.7694 - val_acc: 0.6667
# Epoch 754/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.0300e-04 - acc: 1.0000 - val_loss: 3.7702 - val_acc: 0.6667
# Epoch 755/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.0252e-04 - acc: 1.0000 - val_loss: 3.7740 - val_acc: 0.6667
# Epoch 756/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.0195e-04 - acc: 1.0000 - val_loss: 3.7794 - val_acc: 0.6667
# Epoch 757/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.0144e-04 - acc: 1.0000 - val_loss: 3.7806 - val_acc: 0.6667
# Epoch 758/800
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0090e-04 - acc: 1.0000 - val_loss: 3.7822 - val_acc: 0.6667
# Epoch 759/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.0039e-04 - acc: 1.0000 - val_loss: 3.7849 - val_acc: 0.6667
# Epoch 760/800
# 1/1 [==============================] - 0s 31ms/step - loss: 9.9916e-05 - acc: 1.0000 - val_loss: 3.7868 - val_acc: 0.6667
# Epoch 761/800
# 1/1 [==============================] - 0s 33ms/step - loss: 9.9399e-05 - acc: 1.0000 - val_loss: 3.7872 - val_acc: 0.6667
# Epoch 762/800
# 1/1 [==============================] - 0s 32ms/step - loss: 9.8903e-05 - acc: 1.0000 - val_loss: 3.7890 - val_acc: 0.6667
# Epoch 763/800
# 1/1 [==============================] - 0s 32ms/step - loss: 9.8456e-05 - acc: 1.0000 - val_loss: 3.7906 - val_acc: 0.6667
# Epoch 764/800
# 1/1 [==============================] - 0s 38ms/step - loss: 9.7959e-05 - acc: 1.0000 - val_loss: 3.7922 - val_acc: 0.6667
# Epoch 765/800
# 1/1 [==============================] - 0s 34ms/step - loss: 9.7463e-05 - acc: 1.0000 - val_loss: 3.7953 - val_acc: 0.6667
# Epoch 766/800
# 1/1 [==============================] - 0s 32ms/step - loss: 9.7045e-05 - acc: 1.0000 - val_loss: 3.7956 - val_acc: 0.6667
# Epoch 767/800
# 1/1 [==============================] - 0s 32ms/step - loss: 9.6569e-05 - acc: 1.0000 - val_loss: 3.7964 - val_acc: 0.6667
# Epoch 768/800
# 1/1 [==============================] - 0s 44ms/step - loss: 9.6112e-05 - acc: 1.0000 - val_loss: 3.7993 - val_acc: 0.6667
# Epoch 769/800
# 1/1 [==============================] - 0s 37ms/step - loss: 9.5645e-05 - acc: 1.0000 - val_loss: 3.8025 - val_acc: 0.6667
# Epoch 770/800
# 1/1 [==============================] - 0s 32ms/step - loss: 9.5198e-05 - acc: 1.0000 - val_loss: 3.8033 - val_acc: 0.6667
# Epoch 771/800
# 1/1 [==============================] - 0s 36ms/step - loss: 9.4701e-05 - acc: 1.0000 - val_loss: 3.8042 - val_acc: 0.6667
# Epoch 772/800
# 1/1 [==============================] - 0s 37ms/step - loss: 9.4245e-05 - acc: 1.0000 - val_loss: 3.8068 - val_acc: 0.6667
# Epoch 773/800
# 1/1 [==============================] - 0s 35ms/step - loss: 9.3808e-05 - acc: 1.0000 - val_loss: 3.8089 - val_acc: 0.6667
# Epoch 774/800
# 1/1 [==============================] - 0s 39ms/step - loss: 9.3331e-05 - acc: 1.0000 - val_loss: 3.8090 - val_acc: 0.6667
# Epoch 775/800
# 1/1 [==============================] - 0s 62ms/step - loss: 9.2884e-05 - acc: 1.0000 - val_loss: 3.8116 - val_acc: 0.6667
# Epoch 776/800
# 1/1 [==============================] - 0s 34ms/step - loss: 9.2427e-05 - acc: 1.0000 - val_loss: 3.8151 - val_acc: 0.6667
# Epoch 777/800
# 1/1 [==============================] - 0s 38ms/step - loss: 9.2070e-05 - acc: 1.0000 - val_loss: 3.8156 - val_acc: 0.6667
# Epoch 778/800
# 1/1 [==============================] - 0s 37ms/step - loss: 9.1573e-05 - acc: 1.0000 - val_loss: 3.8157 - val_acc: 0.6667
# Epoch 779/800
# 1/1 [==============================] - 0s 34ms/step - loss: 9.1215e-05 - acc: 1.0000 - val_loss: 3.8185 - val_acc: 0.6667
# Epoch 780/800
# 1/1 [==============================] - 0s 36ms/step - loss: 9.0739e-05 - acc: 1.0000 - val_loss: 3.8236 - val_acc: 0.6667
# Epoch 781/800
# 1/1 [==============================] - 0s 35ms/step - loss: 9.0351e-05 - acc: 1.0000 - val_loss: 3.8240 - val_acc: 0.6667
# Epoch 782/800
# 1/1 [==============================] - 0s 35ms/step - loss: 8.9845e-05 - acc: 1.0000 - val_loss: 3.8236 - val_acc: 0.6667
# Epoch 783/800
# 1/1 [==============================] - 0s 35ms/step - loss: 8.9467e-05 - acc: 1.0000 - val_loss: 3.8256 - val_acc: 0.6667
# Epoch 784/800
# 1/1 [==============================] - 0s 33ms/step - loss: 8.9080e-05 - acc: 1.0000 - val_loss: 3.8297 - val_acc: 0.6667
# Epoch 785/800
# 1/1 [==============================] - 0s 34ms/step - loss: 8.8633e-05 - acc: 1.0000 - val_loss: 3.8334 - val_acc: 0.6667
# Epoch 786/800
# 1/1 [==============================] - 0s 38ms/step - loss: 8.8266e-05 - acc: 1.0000 - val_loss: 3.8331 - val_acc: 0.6667
# Epoch 787/800
# 1/1 [==============================] - 0s 43ms/step - loss: 8.7769e-05 - acc: 1.0000 - val_loss: 3.8330 - val_acc: 0.6667
# Epoch 788/800
# 1/1 [==============================] - 0s 38ms/step - loss: 8.7391e-05 - acc: 1.0000 - val_loss: 3.8351 - val_acc: 0.6667
# Epoch 789/800
# 1/1 [==============================] - 0s 40ms/step - loss: 8.6984e-05 - acc: 1.0000 - val_loss: 3.8379 - val_acc: 0.6667
# Epoch 790/800
# 1/1 [==============================] - 0s 33ms/step - loss: 8.6567e-05 - acc: 1.0000 - val_loss: 3.8382 - val_acc: 0.6667
# Epoch 791/800
# 1/1 [==============================] - 0s 32ms/step - loss: 8.6160e-05 - acc: 1.0000 - val_loss: 3.8409 - val_acc: 0.6667
# Epoch 792/800
# 1/1 [==============================] - 0s 33ms/step - loss: 8.5763e-05 - acc: 1.0000 - val_loss: 3.8436 - val_acc: 0.6667
# Epoch 793/800
# 1/1 [==============================] - 0s 35ms/step - loss: 8.5395e-05 - acc: 1.0000 - val_loss: 3.8450 - val_acc: 0.6667
# Epoch 794/800
# 1/1 [==============================] - 0s 36ms/step - loss: 8.4988e-05 - acc: 1.0000 - val_loss: 3.8474 - val_acc: 0.6667
# Epoch 795/800
# 1/1 [==============================] - 0s 37ms/step - loss: 8.4591e-05 - acc: 1.0000 - val_loss: 3.8490 - val_acc: 0.6667
# Epoch 796/800
# 1/1 [==============================] - 0s 40ms/step - loss: 8.4213e-05 - acc: 1.0000 - val_loss: 3.8515 - val_acc: 0.6667
# Epoch 797/800
# 1/1 [==============================] - 0s 41ms/step - loss: 8.3826e-05 - acc: 1.0000 - val_loss: 3.8526 - val_acc: 0.6667
# Epoch 798/800
# 1/1 [==============================] - 0s 37ms/step - loss: 8.3439e-05 - acc: 1.0000 - val_loss: 3.8548 - val_acc: 0.6667
# Epoch 799/800
# 1/1 [==============================] - 0s 35ms/step - loss: 8.3011e-05 - acc: 1.0000 - val_loss: 3.8567 - val_acc: 0.6667
# Epoch 800/800
# 1/1 [==============================] - ETA: 0s - loss: 8.2664e-05 - acc: 1.0001/1 [==============================] - 0s 36ms/step - loss: 8.2664e-05 - acc: 1.0000 - val_loss: 3.8559 - val_acc: 0.6667

# %%
model.evaluate(test_data,test_targets)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6381 - acc: 0.8815
# [0.6381217241287231, 0.8814814686775208]

# %% [markdown]
# #### Plot the learning curves
#
# We will now plot two graphs:
# * Epoch vs accuracy
# * Epoch vs loss

# %%
# Run this cell to plot the epoch vs accuracy graph

try:
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
except KeyError:
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Acc')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Validation Set'], loc='lower right')
plt.show()

# %%
#Run this cell to plot the epoch vs loss graph
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# Oh no! We have overfit our dataset. You should now try to now try to mitigate this overfitting.

# %% [markdown]
# #### Reducing overfitting in the model

# %% [markdown]
# You should now define a new regularised model.
# The specs for the regularised model are the same as our original model, with the addition of two dropout layers, weight decay, and a batch normalisation layer.
#
# In particular:
#
# * Add a dropout layer after the 3rd Dense layer
# * Then there should be two more Dense layers with 128 units before a batch normalisation layer
# * Following this, two more Dense layers with 64 units and then another Dropout layer
# * Two more Dense layers with 64 units and then the final 3-way softmax layer
# * Add weight decay (l2 kernel regularisation) in all Dense layers except the final softmax layer

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_regularised_model(input_shape, dropout_rate, weight_decay):
    """
    This function should build a regularised Sequential model according to the above specification.
    The dropout_rate argument in the function should be used to set the Dropout rate for all Dropout layers.
    L2 kernel regularisation (weight decay) should be added using the weight_decay argument to
    set the weight decay coefficient in all Dense layers that use L2 regularisation.
    Ensure the weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument input_shape.
    Your function should return the model.
    """
    model = Sequential([
        Dense(64, input_shape=input_shape, kernel_initializer=tf.keras.initializers.he_uniform(), bias_initializer='ones', activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
        Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)),
        Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)),
        Dropout(dropout_rate),
        Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)),
        Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)),
        tf.keras.layers.BatchNormalization(),
        Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)),
        Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)),
        Dropout(dropout_rate),
        Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)),
        Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)),
        Dense(3, activation='softmax')
    ])
    return model

# %% [markdown]
# #### Instantiate, compile and train the model

# %%
newreg_model = get_regularised_model(train_data[0].shape, 0.5, 0.001)

# Instantiate the model, using a dropout rate of 0.3 and weight decay coefficient of 0.001

# %%
# Compile the model

compile_model(newreg_model)

# %%
# Train the model

reg_history = train_model(newreg_model, train_data, train_targets, epochs=800)

# %%
newreg_model.evaluate(test_data,test_targets)

# %%
#### Plot the learning curves

Let's now plot the loss and accuracy for the training and validation sets.
# Out:
# p - loss: 1.5718 - acc: 0.5833 - val_loss: 1.3181 - val_acc: 1.0000
# Epoch 650/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.2307 - acc: 0.7500 - val_loss: 1.3160 - val_acc: 1.0000
# Epoch 651/800
# 1/1 [==============================] - 0s 38ms/step - loss: 1.2352 - acc: 0.8333 - val_loss: 1.3156 - val_acc: 1.0000
# Epoch 652/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.5346 - acc: 0.4167 - val_loss: 1.3146 - val_acc: 1.0000
# Epoch 653/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.2908 - acc: 0.6667 - val_loss: 1.3142 - val_acc: 1.0000
# Epoch 654/800
# 1/1 [==============================] - 0s 39ms/step - loss: 1.2729 - acc: 0.8333 - val_loss: 1.3123 - val_acc: 1.0000
# Epoch 655/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3393 - acc: 0.5000 - val_loss: 1.3111 - val_acc: 1.0000
# Epoch 656/800
# 1/1 [==============================] - 0s 38ms/step - loss: 1.2593 - acc: 0.5833 - val_loss: 1.3094 - val_acc: 1.0000
# Epoch 657/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.2681 - acc: 0.7500 - val_loss: 1.3077 - val_acc: 1.0000
# Epoch 658/800
# 1/1 [==============================] - 0s 47ms/step - loss: 1.3265 - acc: 0.5833 - val_loss: 1.3059 - val_acc: 1.0000
# Epoch 659/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.2622 - acc: 0.6667 - val_loss: 1.3043 - val_acc: 1.0000
# Epoch 660/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3790 - acc: 0.6667 - val_loss: 1.3036 - val_acc: 1.0000
# Epoch 661/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.2314 - acc: 0.9167 - val_loss: 1.3037 - val_acc: 1.0000
# Epoch 662/800
# 1/1 [==============================] - 0s 43ms/step - loss: 1.3453 - acc: 0.5000 - val_loss: 1.3031 - val_acc: 0.6667
# Epoch 663/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.1854 - acc: 0.8333 - val_loss: 1.3025 - val_acc: 1.0000
# Epoch 664/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1489 - acc: 0.9167 - val_loss: 1.3021 - val_acc: 0.6667
# Epoch 665/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.2998 - acc: 0.8333 - val_loss: 1.3013 - val_acc: 0.6667
# Epoch 666/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.2049 - acc: 0.7500 - val_loss: 1.3012 - val_acc: 0.6667
# Epoch 667/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3722 - acc: 0.7500 - val_loss: 1.3008 - val_acc: 0.6667
# Epoch 668/800
# 1/1 [==============================] - 0s 48ms/step - loss: 1.2311 - acc: 0.8333 - val_loss: 1.3002 - val_acc: 0.6667
# Epoch 669/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.1824 - acc: 0.9167 - val_loss: 1.2994 - val_acc: 0.6667
# Epoch 670/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2407 - acc: 0.8333 - val_loss: 1.2985 - val_acc: 0.6667
# Epoch 671/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.2452 - acc: 0.8333 - val_loss: 1.2989 - val_acc: 0.6667
# Epoch 672/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.2971 - acc: 0.5833 - val_loss: 1.2988 - val_acc: 0.6667
# Epoch 673/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2637 - acc: 0.6667 - val_loss: 1.2991 - val_acc: 1.0000
# Epoch 674/800
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3291 - acc: 0.6667 - val_loss: 1.2987 - val_acc: 0.6667
# Epoch 675/800
# 1/1 [==============================] - 0s 39ms/step - loss: 1.2801 - acc: 0.6667 - val_loss: 1.2985 - val_acc: 0.6667
# Epoch 676/800
# 1/1 [==============================] - 0s 42ms/step - loss: 1.2167 - acc: 0.8333 - val_loss: 1.2979 - val_acc: 0.6667
# Epoch 677/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.3416 - acc: 0.7500 - val_loss: 1.2977 - val_acc: 1.0000
# Epoch 678/800
# 1/1 [==============================] - 0s 43ms/step - loss: 1.2532 - acc: 0.6667 - val_loss: 1.2973 - val_acc: 0.6667
# Epoch 679/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.4283 - acc: 0.7500 - val_loss: 1.2975 - val_acc: 1.0000
# Epoch 680/800
# 1/1 [==============================] - 0s 41ms/step - loss: 1.2163 - acc: 0.8333 - val_loss: 1.2983 - val_acc: 1.0000
# Epoch 681/800
# 1/1 [==============================] - 0s 48ms/step - loss: 1.2251 - acc: 0.8333 - val_loss: 1.2973 - val_acc: 1.0000
# Epoch 682/800
# 1/1 [==============================] - 0s 42ms/step - loss: 1.2640 - acc: 0.6667 - val_loss: 1.2967 - val_acc: 1.0000
# Epoch 683/800
# 1/1 [==============================] - 0s 42ms/step - loss: 1.4213 - acc: 0.6667 - val_loss: 1.2967 - val_acc: 1.0000
# Epoch 684/800
# 1/1 [==============================] - 0s 41ms/step - loss: 1.2310 - acc: 0.6667 - val_loss: 1.2978 - val_acc: 1.0000
# Epoch 685/800
# 1/1 [==============================] - 0s 34ms/step - loss: 1.2028 - acc: 0.8333 - val_loss: 1.2976 - val_acc: 1.0000
# Epoch 686/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.3038 - acc: 0.6667 - val_loss: 1.2976 - val_acc: 1.0000
# Epoch 687/800
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3194 - acc: 0.5833 - val_loss: 1.2974 - val_acc: 1.0000
# Epoch 688/800
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3185 - acc: 0.9167 - val_loss: 1.2973 - val_acc: 1.0000
# Epoch 689/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.3070 - acc: 0.5833 - val_loss: 1.2976 - val_acc: 1.0000
# Epoch 690/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.2975 - acc: 0.7500 - val_loss: 1.2981 - val_acc: 1.0000
# Epoch 691/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3100 - acc: 0.5833 - val_loss: 1.2990 - val_acc: 1.0000
# Epoch 692/800
# 1/1 [==============================] - 0s 42ms/step - loss: 1.4162 - acc: 0.5833 - val_loss: 1.2999 - val_acc: 1.0000
# Epoch 693/800
# 1/1 [==============================] - 0s 48ms/step - loss: 1.3476 - acc: 0.6667 - val_loss: 1.3005 - val_acc: 1.0000
# Epoch 694/800
# 1/1 [==============================] - 0s 52ms/step - loss: 1.2684 - acc: 0.5833 - val_loss: 1.3016 - val_acc: 1.0000
# Epoch 695/800
# 1/1 [==============================] - 0s 59ms/step - loss: 1.1419 - acc: 0.8333 - val_loss: 1.3023 - val_acc: 1.0000
# Epoch 696/800
# 1/1 [==============================] - 0s 55ms/step - loss: 1.4386 - acc: 0.7500 - val_loss: 1.3027 - val_acc: 1.0000
# Epoch 697/800
# 1/1 [==============================] - 0s 99ms/step - loss: 1.2319 - acc: 0.5833 - val_loss: 1.3043 - val_acc: 1.0000
# Epoch 698/800
# 1/1 [==============================] - 0s 56ms/step - loss: 1.2602 - acc: 0.7500 - val_loss: 1.3048 - val_acc: 1.0000
# Epoch 699/800
# 1/1 [==============================] - 0s 65ms/step - loss: 1.3882 - acc: 0.4167 - val_loss: 1.3045 - val_acc: 1.0000
# Epoch 700/800
# 1/1 [==============================] - 0s 57ms/step - loss: 1.1748 - acc: 0.6667 - val_loss: 1.3039 - val_acc: 1.0000
# Epoch 701/800
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1569 - acc: 1.0000 - val_loss: 1.3038 - val_acc: 1.0000
# Epoch 702/800
# 1/1 [==============================] - 0s 41ms/step - loss: 1.1799 - acc: 0.8333 - val_loss: 1.3035 - val_acc: 1.0000
# Epoch 703/800
# 1/1 [==============================] - 0s 46ms/step - loss: 1.2894 - acc: 0.6667 - val_loss: 1.3028 - val_acc: 1.0000
# Epoch 704/800
# 1/1 [==============================] - 0s 44ms/step - loss: 1.2918 - acc: 0.7500 - val_loss: 1.3027 - val_acc: 1.0000
# Epoch 705/800
# 1/1 [==============================] - 0s 38ms/step - loss: 1.1864 - acc: 0.7500 - val_loss: 1.3014 - val_acc: 1.0000
# Epoch 706/800
# 1/1 [==============================] - 0s 35ms/step - loss: 1.2727 - acc: 0.6667 - val_loss: 1.3006 - val_acc: 1.0000
# Epoch 707/800
# 1/1 [==============================] - 0s 41ms/step - loss: 1.1094 - acc: 0.9167 - val_loss: 1.2998 - val_acc: 1.0000
# Epoch 708/800
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2019 - acc: 0.8333 - val_loss: 1.2998 - val_acc: 1.0000
# Epoch 709/800
# 1/1 [==============================] - 0s 36ms/step - loss: 1.2664 - acc: 0.8333 - val_loss: 1.2993 - val_acc: 1.0000
# Epoch 710/800
# 1/1 [==============================] - 0s 44ms/step - loss: 1.3418 - acc: 0.7500 - val_loss: 1.2989 - val_acc: 1.0000
# Epoch 711/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.1867 - acc: 0.8333 - val_loss: 1.2990 - val_acc: 1.0000
# Epoch 712/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.4088 - acc: 0.7500 - val_loss: 1.2999 - val_acc: 1.0000
# Epoch 713/800
# 1/1 [==============================] - 0s 32ms/step - loss: 1.1622 - acc: 0.9167 - val_loss: 1.3004 - val_acc: 1.0000
# Epoch 714/800
# 1/1 [==============================] - 0s 33ms/step - loss: 1.1755 - acc: 0.7500 - val_loss: 1.3013 - val_acc: 1.0000
# Epoch 715/800
# 1/1 [==============================] - 0s 43ms/step - loss: 1.4707 - acc: 0.7500 - val_loss: 1.3006 - val_acc: 1.0000
# Epoch 716/800
# 1/1 [==============================] - 0s 57ms/step - loss: 1.2927 - acc: 0.6667 - val_loss: 1.2993 - val_acc: 1.0000
# Epoch 717/800
# 1/1 [==============================] - 0s 77ms/step - loss: 1.2654 - acc: 0.7500 - val_loss: 1.2997 - val_acc: 1.0000
# Epoch 718/800
# 1/1 [==============================] - 0s 67ms/step - loss: 1.2331 - acc: 0.6667 - val_loss: 1.2996 - val_acc: 1.0000
# Epoch 719/800
# 1/1 [==============================] - 0s 61ms/step - loss: 1.2430 - acc: 0.6667 - val_loss: 1.2988 - val_acc: 1.0000
# Epoch 720/800
# 1/1 [==============================] - 0s 59ms/step - loss: 1.2212 - acc: 0.7500 - val_loss: 1.2987 - val_acc: 1.0000
# Epoch 721/800
# 1/1 [==============================] - 0s 59ms/step - loss: 1.3498 - acc: 0.7500 - val_loss: 1.2988 - val_acc: 1.0000
# Epoch 722/800
# 1/1 [==============================] - 0s 57ms/step - loss: 1.4823 - acc: 0.7500 - val_loss: 1.2989 - val_acc: 1.0000
# Epoch 723/800
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1564 - acc: 0.9167 - val_loss: 1.2985 - val_acc: 1.0000
# Epoch 724/800
# 1/1 [==============================] - 0s 63ms/step - loss: 1.2116 - acc: 0.5833 - val_loss: 1.2985 - val_acc: 1.0000
# Epoch 725/800
# 1/1 [==============================] - 0s 70ms/step - loss: 1.2839 - acc: 0.6667 - val_loss: 1.2998 - val_acc: 1.0000
# Epoch 726/800
# 1/1 [==============================] - 0s 61ms/step - loss: 1.1637 - acc: 0.8333 - val_loss: 1.3010 - val_acc: 1.0000
# Epoch 727/800
# 1/1 [==============================] - 0s 72ms/step - loss: 1.2007 - acc: 0.9167 - val_loss: 1.3019 - val_acc: 1.0000
# Epoch 728/800
# 1/1 [==============================] - 0s 90ms/step - loss: 1.2649 - acc: 0.6667 - val_loss: 1.3026 - val_acc: 1.0000
# Epoch 729/800
# 1/1 [==============================] - 0s 60ms/step - loss: 1.2470 - acc: 0.7500 - val_loss: 1.3034 - val_acc: 1.0000
# Epoch 730/800
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1313 - acc: 0.8333 - val_loss: 1.3049 - val_acc: 1.0000
# Epoch 731/800
# 1/1 [==============================] - 0s 60ms/step - loss: 1.1723 - acc: 0.8333 - val_loss: 1.3051 - val_acc: 1.0000
# Epoch 732/800
# 1/1 [==============================] - 0s 69ms/step - loss: 1.2922 - acc: 0.6667 - val_loss: 1.3065 - val_acc: 1.0000
# Epoch 733/800
# 1/1 [==============================] - 0s 62ms/step - loss: 1.1924 - acc: 0.6667 - val_loss: 1.3075 - val_acc: 1.0000
# Epoch 734/800
# 1/1 [==============================] - 0s 61ms/step - loss: 1.1447 - acc: 0.8333 - val_loss: 1.3087 - val_acc: 1.0000
# Epoch 735/800
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3138 - acc: 0.6667 - val_loss: 1.3099 - val_acc: 1.0000
# Epoch 736/800
# 1/1 [==============================] - 0s 60ms/step - loss: 1.3144 - acc: 0.5000 - val_loss: 1.3114 - val_acc: 1.0000
# Epoch 737/800
# 1/1 [==============================] - 0s 84ms/step - loss: 1.2861 - acc: 0.7500 - val_loss: 1.3120 - val_acc: 1.0000
# Epoch 738/800
# 1/1 [==============================] - 0s 59ms/step - loss: 1.2494 - acc: 0.7500 - val_loss: 1.3117 - val_acc: 1.0000
# Epoch 739/800
# 1/1 [==============================] - 0s 58ms/step - loss: 1.1802 - acc: 0.7500 - val_loss: 1.3109 - val_acc: 1.0000
# Epoch 740/800
# 1/1 [==============================] - 0s 67ms/step - loss: 1.2877 - acc: 0.5833 - val_loss: 1.3108 - val_acc: 1.0000
# Epoch 741/800
# 1/1 [==============================] - 0s 57ms/step - loss: 1.2020 - acc: 0.7500 - val_loss: 1.3107 - val_acc: 1.0000
# Epoch 742/800
# 1/1 [==============================] - 0s 61ms/step - loss: 1.2307 - acc: 0.7500 - val_loss: 1.3109 - val_acc: 1.0000
# Epoch 743/800
# 1/1 [==============================] - 0s 63ms/step - loss: 1.1400 - acc: 0.7500 - val_loss: 1.3108 - val_acc: 1.0000
# Epoch 744/800
# 1/1 [==============================] - 0s 63ms/step - loss: 1.2444 - acc: 0.7500 - val_loss: 1.3108 - val_acc: 1.0000
# Epoch 745/800
# 1/1 [==============================] - 0s 59ms/step - loss: 1.1900 - acc: 0.6667 - val_loss: 1.3113 - val_acc: 1.0000
# Epoch 746/800
# 1/1 [==============================] - 0s 71ms/step - loss: 1.1550 - acc: 0.9167 - val_loss: 1.3122 - val_acc: 1.0000
# Epoch 747/800
# 1/1 [==============================] - 0s 57ms/step - loss: 1.2276 - acc: 0.6667 - val_loss: 1.3130 - val_acc: 1.0000
# Epoch 748/800
# 1/1 [==============================] - 0s 59ms/step - loss: 1.1987 - acc: 0.8333 - val_loss: 1.3118 - val_acc: 1.0000
# Epoch 749/800
# 1/1 [==============================] - 0s 62ms/step - loss: 1.2505 - acc: 0.7500 - val_loss: 1.3105 - val_acc: 1.0000
# Epoch 750/800
# 1/1 [==============================] - 0s 65ms/step - loss: 1.2186 - acc: 0.6667 - val_loss: 1.3106 - val_acc: 1.0000
# Epoch 751/800
# 1/1 [==============================] - 0s 57ms/step - loss: 1.1549 - acc: 0.7500 - val_loss: 1.3101 - val_acc: 1.0000
# Epoch 752/800
# 1/1 [==============================] - 0s 58ms/step - loss: 1.1676 - acc: 0.7500 - val_loss: 1.3107 - val_acc: 1.0000
# Epoch 753/800
# 1/1 [==============================] - 0s 62ms/step - loss: 1.1665 - acc: 0.8333 - val_loss: 1.3099 - val_acc: 1.0000
# Epoch 754/800
# 1/1 [==============================] - 0s 65ms/step - loss: 1.2160 - acc: 0.9167 - val_loss: 1.3094 - val_acc: 1.0000
# Epoch 755/800
# 1/1 [==============================] - 0s 62ms/step - loss: 1.1350 - acc: 0.7500 - val_loss: 1.3092 - val_acc: 1.0000
# Epoch 756/800
# 1/1 [==============================] - 0s 74ms/step - loss: 1.1416 - acc: 0.9167 - val_loss: 1.3099 - val_acc: 1.0000
# Epoch 757/800
# 1/1 [==============================] - 0s 57ms/step - loss: 1.1306 - acc: 0.7500 - val_loss: 1.3104 - val_acc: 1.0000
# Epoch 758/800
# 1/1 [==============================] - 0s 57ms/step - loss: 1.0514 - acc: 0.7500 - val_loss: 1.3111 - val_acc: 1.0000
# Epoch 759/800
# 1/1 [==============================] - 0s 58ms/step - loss: 1.1566 - acc: 0.7500 - val_loss: 1.3112 - val_acc: 1.0000
# Epoch 760/800
# 1/1 [==============================] - 0s 60ms/step - loss: 1.1982 - acc: 0.7500 - val_loss: 1.3115 - val_acc: 1.0000
# Epoch 761/800
# 1/1 [==============================] - 0s 56ms/step - loss: 1.2222 - acc: 0.7500 - val_loss: 1.3117 - val_acc: 1.0000
# Epoch 762/800
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1445 - acc: 0.8333 - val_loss: 1.3118 - val_acc: 1.0000
# Epoch 763/800
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3405 - acc: 0.7500 - val_loss: 1.3118 - val_acc: 1.0000
# Epoch 764/800
# 1/1 [==============================] - 0s 56ms/step - loss: 1.1836 - acc: 0.7500 - val_loss: 1.3114 - val_acc: 1.0000
# Epoch 765/800
# 1/1 [==============================] - 0s 57ms/step - loss: 1.1786 - acc: 0.9167 - val_loss: 1.3123 - val_acc: 0.6667
# Epoch 766/800
# 1/1 [==============================] - 0s 73ms/step - loss: 1.2760 - acc: 0.5833 - val_loss: 1.3125 - val_acc: 0.6667
# Epoch 767/800
# 1/1 [==============================] - 0s 61ms/step - loss: 1.0646 - acc: 1.0000 - val_loss: 1.3122 - val_acc: 0.6667
# Epoch 768/800
# 1/1 [==============================] - 0s 80ms/step - loss: 1.2939 - acc: 0.5833 - val_loss: 1.3120 - val_acc: 0.6667
# Epoch 769/800
# 1/1 [==============================] - 0s 75ms/step - loss: 1.3261 - acc: 0.5833 - val_loss: 1.3130 - val_acc: 0.6667
# Epoch 770/800
# 1/1 [==============================] - 0s 76ms/step - loss: 1.0562 - acc: 0.8333 - val_loss: 1.3133 - val_acc: 0.6667
# Epoch 771/800
# 1/1 [==============================] - 0s 67ms/step - loss: 1.0892 - acc: 0.8333 - val_loss: 1.3128 - val_acc: 0.6667
# Epoch 772/800
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1240 - acc: 0.8333 - val_loss: 1.3120 - val_acc: 0.6667
# Epoch 773/800
# 1/1 [==============================] - 0s 58ms/step - loss: 1.2111 - acc: 0.5833 - val_loss: 1.3114 - val_acc: 0.6667
# Epoch 774/800
# 1/1 [==============================] - 0s 63ms/step - loss: 1.2926 - acc: 0.5833 - val_loss: 1.3105 - val_acc: 0.6667
# Epoch 775/800
# 1/1 [==============================] - 0s 69ms/step - loss: 1.1238 - acc: 0.9167 - val_loss: 1.3095 - val_acc: 0.6667
# Epoch 776/800
# 1/1 [==============================] - 0s 72ms/step - loss: 1.1156 - acc: 0.8333 - val_loss: 1.3098 - val_acc: 0.6667
# Epoch 777/800
# 1/1 [==============================] - 0s 61ms/step - loss: 1.1658 - acc: 0.7500 - val_loss: 1.3094 - val_acc: 0.6667
# Epoch 778/800
# 1/1 [==============================] - 0s 65ms/step - loss: 1.2411 - acc: 0.5833 - val_loss: 1.3092 - val_acc: 0.6667
# Epoch 779/800
# 1/1 [==============================] - 0s 61ms/step - loss: 1.1027 - acc: 0.7500 - val_loss: 1.3103 - val_acc: 0.6667
# Epoch 780/800
# 1/1 [==============================] - 0s 62ms/step - loss: 1.2034 - acc: 0.6667 - val_loss: 1.3116 - val_acc: 0.6667
# Epoch 781/800
# 1/1 [==============================] - 0s 60ms/step - loss: 1.1656 - acc: 0.6667 - val_loss: 1.3107 - val_acc: 0.6667
# Epoch 782/800
# 1/1 [==============================] - 0s 59ms/step - loss: 1.2465 - acc: 0.6667 - val_loss: 1.3104 - val_acc: 0.6667
# Epoch 783/800
# 1/1 [==============================] - 0s 63ms/step - loss: 1.3142 - acc: 0.6667 - val_loss: 1.3100 - val_acc: 0.6667
# Epoch 784/800
# 1/1 [==============================] - 0s 90ms/step - loss: 1.3351 - acc: 0.7500 - val_loss: 1.3101 - val_acc: 0.6667
# Epoch 785/800
# 1/1 [==============================] - 0s 58ms/step - loss: 1.0632 - acc: 1.0000 - val_loss: 1.3108 - val_acc: 0.6667
# Epoch 786/800
# 1/1 [==============================] - 0s 78ms/step - loss: 1.1989 - acc: 0.7500 - val_loss: 1.3101 - val_acc: 0.6667
# Epoch 787/800
# 1/1 [==============================] - 0s 58ms/step - loss: 1.1332 - acc: 0.9167 - val_loss: 1.3090 - val_acc: 0.6667
# Epoch 788/800
# 1/1 [==============================] - 0s 62ms/step - loss: 1.1779 - acc: 0.7500 - val_loss: 1.3069 - val_acc: 0.6667
# Epoch 789/800
# 1/1 [==============================] - 0s 70ms/step - loss: 1.1087 - acc: 0.9167 - val_loss: 1.3056 - val_acc: 0.6667
# Epoch 790/800
# 1/1 [==============================] - 0s 61ms/step - loss: 1.1610 - acc: 0.7500 - val_loss: 1.3038 - val_acc: 0.6667
# Epoch 791/800
# 1/1 [==============================] - 0s 59ms/step - loss: 1.1738 - acc: 0.7500 - val_loss: 1.3027 - val_acc: 0.6667
# Epoch 792/800
# 1/1 [==============================] - 0s 73ms/step - loss: 1.2093 - acc: 0.6667 - val_loss: 1.3016 - val_acc: 0.6667
# Epoch 793/800
# 1/1 [==============================] - 0s 58ms/step - loss: 1.1250 - acc: 0.7500 - val_loss: 1.2999 - val_acc: 0.6667
# Epoch 794/800
# 1/1 [==============================] - 0s 58ms/step - loss: 1.2470 - acc: 0.8333 - val_loss: 1.2986 - val_acc: 0.6667
# Epoch 795/800
# 1/1 [==============================] - 0s 59ms/step - loss: 1.2539 - acc: 0.8333 - val_loss: 1.2966 - val_acc: 0.6667
# Epoch 796/800
# 1/1 [==============================] - 0s 70ms/step - loss: 1.2597 - acc: 0.6667 - val_loss: 1.2956 - val_acc: 0.6667
# Epoch 797/800
# 1/1 [==============================] - 0s 59ms/step - loss: 1.2534 - acc: 0.6667 - val_loss: 1.2950 - val_acc: 0.6667
# Epoch 798/800
# 1/1 [==============================] - 0s 66ms/step - loss: 1.1935 - acc: 0.7500 - val_loss: 1.2947 - val_acc: 0.6667
# Epoch 799/800
# 1/1 [==============================] - 0s 61ms/step - loss: 1.2025 - acc: 0.7500 - val_loss: 1.2938 - val_acc: 0.6667
# Epoch 800/800
# 1/1 [==============================] - 0s 62ms/step - loss: 1.1422 - acc: 0.8333 - val_loss: 1.2942 - val_acc: 0.6667

# %%
newreg_model.evaluate(test_data,test_targets)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 1.0851 - acc: 0.9481
# [1.0851020812988281, 0.9481481313705444]

# %% [markdown]
# #### Plot the learning curves
#
# Let's now plot the loss and accuracy for the training and validation sets.

# %%
#Run this cell to plot the new accuracy vs epoch graph

try:
    plt.plot(reg_history.history['accuracy'])
    plt.plot(reg_history.history['val_accuracy'])
except KeyError:
    plt.plot(reg_history.history['acc'])
    plt.plot(reg_history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %%
#Run this cell to plot the new loss vs epoch graph

plt.plot(reg_history.history['loss'])
plt.plot(reg_history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# We can see that the regularisation has helped to reduce the overfitting of the network.
# You will now incorporate callbacks into a new training run that implements early stopping and learning rate reduction on plateaux.
#
# Fill in the function below so that:
#
# * It creates an `EarlyStopping` callback object and a `ReduceLROnPlateau` callback object
# * The early stopping callback is used and monitors validation loss with the mode set to `"min"` and patience of 30.
# * The learning rate reduction on plateaux is used with a learning rate factor of 0.2 and a patience of 20.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_callbacks():
    """
    This function should create and return a tuple (early_stopping, learning_rate_reduction) callbacks.
    The callbacks should be instantiated according to the above requirements.
    """
    earlstop = tf.keras.callbacks.EarlyStopping( monitor='val_loss', patience=30, mode='min')
    lrr = tf.keras.callbacks.ReduceLROnPlateau(patience=20, factor=0.2)
    return earlstop,lrr

# %% [markdown]
# Run the cell below to instantiate and train the regularised model with the callbacks.

# %%
call_model = get_regularised_model(train_data[0].shape, 0.3, 0.0001)
compile_model(call_model)
early_stopping, learning_rate_reduction = get_callbacks()
call_history = call_model.fit(train_data, train_targets, epochs=800, validation_split=0.15,
                         callbacks=[early_stopping, learning_rate_reduction], verbose=0)

# %%
learning_rate_reduction.patience
# Out:
# 20

# %% [markdown]
# Finally, let's replot the accuracy and loss graphs for our new model.

# %%
try:
    plt.plot(call_history.history['accuracy'])
    plt.plot(call_history.history['val_accuracy'])
except KeyError:
    plt.plot(call_history.history['acc'])
    plt.plot(call_history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %%
plt.plot(call_history.history['loss'])
plt.plot(call_history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
# Evaluate the model on the test set

test_loss, test_acc = call_model.evaluate(test_data, test_targets, verbose=0)
print("Test loss: {:.3f}\nTest accuracy: {:.2f}%".format(test_loss, 100 * test_acc))
# Out:
# Test loss: 1.142
# Test accuracy: 96.30%

# %% [markdown]
# Congratulations for completing this programming assignment! In the next week of the course we will learn how to save and load pre-trained models.
